# %%
import pandas as pd

# %%
database_type = "/training"

# %% [markdown]
# #### Reading in Training Tables

# %%
lab = pd.read_csv('../eICU' + database_type + '/lab.csv')
lab
# Out:
#         patientunitstayid  labresultoffset  creatinine  wbcx1000  lactate
# 0                  141227             1362        1.90      42.7      NaN
# 1                  141227            -1566        1.40      48.2      NaN
# 2                  141227              -13        1.50      65.9      4.3
# 3                  141227              937        1.60       NaN      NaN
# 4                  141227             -128        1.40      47.7      NaN
# 5                  141288             3697        0.60      11.5      NaN
# 6                  141288             2202        0.66      16.0      NaN
# 7                  141288             6544        0.54      13.0      NaN
# 8                  141288             5097        0.71      11.9      NaN
# 9                  141288              797        0.73      16.3      1.1
# 10                 141288             -268        0.95       6.9      3.2
# 11                 141289              595        0.60       7.1      NaN
# 12                 141297             1838        4.37      16.8     15.5
# 13                 141297              788        6.18      11.4      NaN
# 14                 141297              193        5.69      17.3      3.0
# 15                 141304             -127        2.34      16.4      1.5
# 16                 141304             2978        1.47      15.5      NaN
# 17                 141304             1606        1.28      11.8      NaN
# 18                 141304             4409        1.29      13.6      NaN
# 19                 141304             5800        1.24      12.6      NaN
# 20                 141304               93        2.05      12.8      NaN
# 21                 141304             7293        1.29      11.7      NaN
# 22                 141314               33        1.67       5.8     23.5
# 23                 141314              507        1.91       1.9     20.5
# 24                 141314              343        1.84       4.0      NaN
# 25                 141362            18067        1.06      10.7      NaN
# 26                 141362            16637        0.92      10.0      NaN
# 27                 141362            10871        1.00      14.9      NaN
# 28                 141362              746        1.13      10.3      NaN
# 29                 141362             -639        1.11      14.2      NaN
# ...                   ...              ...         ...       ...      ...
# 335835            3353199             8559        0.76       NaN      NaN
# 335836            3353199             2461        0.96       5.7      NaN
# 335837            3353199             5335        0.71       NaN      NaN
# 335838            3353235             -310        1.04       5.4      NaN
# 335839            3353235             1738        1.19       NaN      NaN
# 335840            3353251            11058        3.98      17.6      NaN
# 335841            3353251            13970        4.02       NaN      NaN
# 335842            3353251            18327        2.28      18.3      NaN
# 335843            3353251             8246        3.29      13.6      NaN
# 335844            3353251            16867        2.78       NaN      NaN
# 335845            3353251            12458        3.94      18.6      NaN
# 335846            3353251             9644        3.79      15.4      NaN
# 335847            3353251              765        2.65      25.9      NaN
# 335848            3353251            15598        3.23       NaN      NaN
# 335849            3353251             1490        2.40      20.8      NaN
# 335850            3353251              995        2.60      21.5      NaN
# 335851            3353251             3863        3.40      14.4      NaN
# 335852            3353251             2541        3.08      26.1      NaN
# 335853            3353251             1127        2.41      20.4      NaN
# 335854            3353251             -217        1.81       NaN      NaN
# 335855            3353251             5459        3.29      11.9      NaN
# 335856            3353251             6868        3.35      13.0      NaN
# 335857            3353251             1849        2.46      25.9      NaN
# 335858            3353251              409        2.43       NaN      NaN
# 335859            3353254             2610        1.92       9.8      NaN
# 335860            3353254             1844        2.22       NaN      NaN
# 335861            3353254             1218        2.21      15.3      NaN
# 335862            3353254             5558        1.67      11.7      NaN
# 335863            3353254             4144        1.61       NaN      NaN
# 335864            3353254             -256        2.38      13.5      NaN
#
# [335865 rows x 5 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
vitalperiodic = pd.read_csv('../eICU' + database_type + '/vitalPeriodic.csv')
vitalperiodic
# Out:
#           patientunitstayid  observationoffset  temperature  heartrate  \
# 0                    141227               1162          NaN      100.0
# 1                    141227               1062          NaN      100.0
# 2                    141227               1192          NaN      106.0
# 3                    141227                522          NaN      110.0
# 4                    141227               1197          NaN      106.0
# 5                    141227               1017          NaN       96.0
# 6                    141227               1142          NaN       96.0
# 7                    141227                242          NaN      102.0
# 8                    141227               1127          NaN       96.0
# 9                    141227               1067          NaN      100.0
# 10                   141227               1107          NaN      102.0
# 11                   141227               1417          NaN      124.0
# 12                   141227               1082          NaN      102.0
# 13                   141227               1012          NaN       96.0
# 14                   141227               1087          NaN      100.0
# 15                   141227                502          NaN      112.0
# 16                   141227               1092          NaN      100.0
# 17                   141227                962          NaN      112.0
# 18                   141227               1167          NaN      104.0
# 19                   141227                267          NaN       96.0
# 20                   141227               1097          NaN      102.0
# 21                   141227               1032          NaN       96.0
# 22                   141227               1102          NaN      104.0
# 23                   141227                712          NaN      204.0
# 24                   141227               1187          NaN      104.0
# 25                   141227               1002          NaN       98.0
# 26                   141227               1112          NaN      100.0
# 27                   141227                507          NaN      110.0
# 28                   141227               1172          NaN      102.0
# 29                   141227               1007          NaN       98.0
# ...                     ...                ...          ...        ...
# 40642091            3353254                 34          NaN       83.0
# 40642092            3353254                379          NaN       76.0
# 40642093            3353254                304          NaN       74.0
# 40642094            3353254                119          NaN       76.0
# 40642095            3353254                169          NaN       76.0
# 40642096            3353254                294          NaN       74.0
# 40642097            3353254                 24          NaN       76.0
# 40642098            3353254                374          NaN       78.0
# 40642099            3353254                299          NaN       75.0
# 40642100            3353254                 59          NaN       80.0
# 40642101            3353254                174          NaN       76.0
# 40642102            3353254                309          NaN       75.0
# 40642103            3353254                424          NaN       83.0
# 40642104            3353254                314          NaN       75.0
# 40642105            3353254                144          NaN       75.0
# 40642106            3353254                319          NaN       75.0
# 40642107            3353254                384          NaN       77.0
# 40642108            3353254                239          NaN       72.0
# 40642109            3353254                414          NaN       83.0
# 40642110            3353254                234          NaN       73.0
# 40642111            3353254                194          NaN       76.0
# 40642112            3353254                189          NaN       76.0
# 40642113            3353254                134          NaN       74.0
# 40642114            3353254                139          NaN       75.0
# 40642115            3353254                229          NaN       73.0
# 40642116            3353254                214          NaN       76.0
# 40642117            3353254                129          NaN       74.0
# 40642118            3353254                184          NaN       76.0
# 40642119            3353254                209          NaN       76.0
# 40642120            3353254                124          NaN       75.0
#
#           respiration  systemicsystolic
# 0                31.0               NaN
# 1                31.0               NaN
# 2                35.0             130.0
# 3                33.0               NaN
# 4                36.0             124.0
# 5                35.0              97.0
# 6                30.0               NaN
# 7                31.0               NaN
# 8                29.0               NaN
# 9                31.0               NaN
# 10               31.0               NaN
# 11               31.0              80.0
# 12               32.0               NaN
# 13               35.0             100.0
# 14               31.0               NaN
# 15               36.0               NaN
# 16               31.0               NaN
# 17               51.0               NaN
# 18               33.0               NaN
# 19               24.0               NaN
# 20               33.0               NaN
# 21               33.0               NaN
# 22               32.0               NaN
# 23               41.0              76.0
# 24               34.0               NaN
# 25               35.0              77.0
# 26               29.0               NaN
# 27               34.0               NaN
# 28               33.0               NaN
# 29               34.0              94.0
# ...               ...               ...
# 40642091         10.0               NaN
# 40642092         22.0               NaN
# 40642093         23.0               NaN
# 40642094         26.0               NaN
# 40642095         26.0               NaN
# 40642096         23.0               NaN
# 40642097         17.0               NaN
# 40642098         28.0               NaN
# 40642099         23.0               NaN
# 40642100         25.0               NaN
# 40642101         23.0               NaN
# 40642102         21.0               NaN
# 40642103          9.0               NaN
# 40642104         24.0               NaN
# 40642105         20.0               NaN
# 40642106         24.0               NaN
# 40642107         23.0               NaN
# 40642108         20.0               NaN
# 40642109         25.0               NaN
# 40642110         19.0               NaN
# 40642111         22.0               NaN
# 40642112         21.0               NaN
# 40642113         20.0               NaN
# 40642114         21.0               NaN
# 40642115         20.0               NaN
# 40642116         21.0               NaN
# 40642117         22.0               NaN
# 40642118         22.0               NaN
# 40642119         20.0               NaN
# 40642120         23.0               NaN
#
# [40642121 rows x 6 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
# The original dataframes were deleted to free up resources.  
merge = pd.merge(vitalperiodic, lab,  how='outer', left_on=['patientunitstayid','observationoffset'], right_on = ['patientunitstayid','labresultoffset'])
del lab, vitalperiodic
merge
# Out:
#           patientunitstayid  observationoffset  temperature  heartrate  \
# 0                    141227             1162.0          NaN      100.0
# 1                    141227             1062.0          NaN      100.0
# 2                    141227             1192.0          NaN      106.0
# 3                    141227              522.0          NaN      110.0
# 4                    141227             1197.0          NaN      106.0
# 5                    141227             1017.0          NaN       96.0
# 6                    141227             1142.0          NaN       96.0
# 7                    141227              242.0          NaN      102.0
# 8                    141227             1127.0          NaN       96.0
# 9                    141227             1067.0          NaN      100.0
# 10                   141227             1107.0          NaN      102.0
# 11                   141227             1417.0          NaN      124.0
# 12                   141227             1082.0          NaN      102.0
# 13                   141227             1012.0          NaN       96.0
# 14                   141227             1087.0          NaN      100.0
# 15                   141227              502.0          NaN      112.0
# 16                   141227             1092.0          NaN      100.0
# 17                   141227              962.0          NaN      112.0
# 18                   141227             1167.0          NaN      104.0
# 19                   141227              267.0          NaN       96.0
# 20                   141227             1097.0          NaN      102.0
# 21                   141227             1032.0          NaN       96.0
# 22                   141227             1102.0          NaN      104.0
# 23                   141227              712.0          NaN      204.0
# 24                   141227             1187.0          NaN      104.0
# 25                   141227             1002.0          NaN       98.0
# 26                   141227             1112.0          NaN      100.0
# 27                   141227              507.0          NaN      110.0
# 28                   141227             1172.0          NaN      102.0
# 29                   141227             1007.0          NaN       98.0
# ...                     ...                ...          ...        ...
# 40940677            3353197                NaN          NaN        NaN
# 40940678            3353197                NaN          NaN        NaN
# 40940679            3353197                NaN          NaN        NaN
# 40940680            3353199                NaN          NaN        NaN
# 40940681            3353199                NaN          NaN        NaN
# 40940682            3353199                NaN          NaN        NaN
# 40940683            3353199                NaN          NaN        NaN
# 40940684            3353235                NaN          NaN        NaN
# 40940685            3353235                NaN          NaN        NaN
# 40940686            3353251                NaN          NaN        NaN
# 40940687            3353251                NaN          NaN        NaN
# 40940688            3353251                NaN          NaN        NaN
# 40940689            3353251                NaN          NaN        NaN
# 40940690            3353251                NaN          NaN        NaN
# 40940691            3353251                NaN          NaN        NaN
# 40940692            3353251                NaN          NaN        NaN
# 40940693            3353251                NaN          NaN        NaN
# 40940694            3353251                NaN          NaN        NaN
# 40940695            3353251                NaN          NaN        NaN
# 40940696            3353251                NaN          NaN        NaN
# 40940697            3353251                NaN          NaN        NaN
# 40940698            3353251                NaN          NaN        NaN
# 40940699            3353251                NaN          NaN        NaN
# 40940700            3353251                NaN          NaN        NaN
# 40940701            3353254                NaN          NaN        NaN
# 40940702            3353254                NaN          NaN        NaN
# 40940703            3353254                NaN          NaN        NaN
# 40940704            3353254                NaN          NaN        NaN
# 40940705            3353254                NaN          NaN        NaN
# 40940706            3353254                NaN          NaN        NaN
#
#           respiration  systemicsystolic  labresultoffset  creatinine  \
# 0                31.0               NaN              NaN         NaN
# 1                31.0               NaN              NaN         NaN
# 2                35.0             130.0              NaN         NaN
# 3                33.0               NaN              NaN         NaN
# 4                36.0             124.0              NaN         NaN
# 5                35.0              97.0              NaN         NaN
# 6                30.0               NaN              NaN         NaN
# 7                31.0               NaN              NaN         NaN
# 8                29.0               NaN              NaN         NaN
# 9                31.0               NaN              NaN         NaN
# 10               31.0               NaN              NaN         NaN
# 11               31.0              80.0              NaN         NaN
# 12               32.0               NaN              NaN         NaN
# 13               35.0             100.0              NaN         NaN
# 14               31.0               NaN              NaN         NaN
# 15               36.0               NaN              NaN         NaN
# 16               31.0               NaN              NaN         NaN
# 17               51.0               NaN              NaN         NaN
# 18               33.0               NaN              NaN         NaN
# 19               24.0               NaN              NaN         NaN
# 20               33.0               NaN              NaN         NaN
# 21               33.0               NaN              NaN         NaN
# 22               32.0               NaN              NaN         NaN
# 23               41.0              76.0              NaN         NaN
# 24               34.0               NaN              NaN         NaN
# 25               35.0              77.0              NaN         NaN
# 26               29.0               NaN              NaN         NaN
# 27               34.0               NaN              NaN         NaN
# 28               33.0               NaN              NaN         NaN
# 29               34.0              94.0              NaN         NaN
# ...               ...               ...              ...         ...
# 40940677          NaN               NaN             20.0        0.71
# 40940678          NaN               NaN          12087.0        1.54
# 40940679          NaN               NaN           9227.0        1.70
# 40940680          NaN               NaN           3932.0        0.85
# 40940681          NaN               NaN            972.0        0.95
# 40940682          NaN               NaN           8559.0        0.76
# 40940683          NaN               NaN           5335.0        0.71
# 40940684          NaN               NaN           -310.0        1.04
# 40940685          NaN               NaN           1738.0        1.19
# 40940686          NaN               NaN          11058.0        3.98
# 40940687          NaN               NaN          13970.0        4.02
# 40940688          NaN               NaN          18327.0        2.28
# 40940689          NaN               NaN           8246.0        3.29
# 40940690          NaN               NaN          16867.0        2.78
# 40940691          NaN               NaN          12458.0        3.94
# 40940692          NaN               NaN            765.0        2.65
# 40940693          NaN               NaN          15598.0        3.23
# 40940694          NaN               NaN           1490.0        2.40
# 40940695          NaN               NaN            995.0        2.60
# 40940696          NaN               NaN           3863.0        3.40
# 40940697          NaN               NaN           2541.0        3.08
# 40940698          NaN               NaN           1127.0        2.41
# 40940699          NaN               NaN           -217.0        1.81
# 40940700          NaN               NaN           6868.0        3.35
# 40940701          NaN               NaN           2610.0        1.92
# 40940702          NaN               NaN           1844.0        2.22
# 40940703          NaN               NaN           1218.0        2.21
# 40940704          NaN               NaN           5558.0        1.67
# 40940705          NaN               NaN           4144.0        1.61
# 40940706          NaN               NaN           -256.0        2.38
#
#           wbcx1000  lactate
# 0              NaN      NaN
# 1              NaN      NaN
# 2              NaN      NaN
# 3              NaN      NaN
# 4              NaN      NaN
# 5              NaN      NaN
# 6              NaN      NaN
# 7              NaN      NaN
# 8              NaN      NaN
# 9              NaN      NaN
# 10             NaN      NaN
# 11             NaN      NaN
# 12             NaN      NaN
# 13             NaN      NaN
# 14             NaN      NaN
# 15             NaN      NaN
# 16             NaN      NaN
# 17             NaN      NaN
# 18             NaN      NaN
# 19             NaN      NaN
# 20             NaN      NaN
# 21             NaN      NaN
# 22             NaN      NaN
# 23             NaN      NaN
# 24             NaN      NaN
# 25             NaN      NaN
# 26             NaN      NaN
# 27             NaN      NaN
# 28             NaN      NaN
# 29             NaN      NaN
# ...            ...      ...
# 40940677      11.2      NaN
# 40940678      26.6      NaN
# 40940679      14.0      NaN
# 40940680       8.6      NaN
# 40940681       6.6      NaN
# 40940682       NaN      NaN
# 40940683       NaN      NaN
# 40940684       5.4      NaN
# 40940685       NaN      NaN
# 40940686      17.6      NaN
# 40940687       NaN      NaN
# 40940688      18.3      NaN
# 40940689      13.6      NaN
# 40940690       NaN      NaN
# 40940691      18.6      NaN
# 40940692      25.9      NaN
# 40940693       NaN      NaN
# 40940694      20.8      NaN
# 40940695      21.5      NaN
# 40940696      14.4      NaN
# 40940697      26.1      NaN
# 40940698      20.4      NaN
# 40940699       NaN      NaN
# 40940700      13.0      NaN
# 40940701       9.8      NaN
# 40940702       NaN      NaN
# 40940703      15.3      NaN
# 40940704      11.7      NaN
# 40940705       NaN      NaN
# 40940706      13.5      NaN
#
# [40940707 rows x 10 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
intakeOutputUrine = pd.read_csv('../eICU' + database_type + '/intakeOutputUrine.csv')
intakeOutputUrine
# Out:
#         patientunitstayid  intakeoutputoffset  urineoutputbyweight
# 0                  141227               -1893             2.433090
# 1                  141227               -1663             2.433090
# 2                  141227               -1773             2.433090
# 3                  141227               -1351             2.433090
# 4                  141288                2737             6.006006
# 5                  141289                 835             1.171171
# 6                  141289                1255             1.051051
# 7                  141289                1015             0.360360
# 8                  141304               10842             1.540832
# 9                  141304               10157             2.439651
# 10                 141304               10023             1.284027
# 11                 141304                8217             2.568053
# 12                 141304                8949             1.540832
# 13                 141304                8463             1.540832
# 14                 141304               10739             2.568053
# 15                 141304               10394             2.311248
# 16                 141304                8960             1.797637
# 17                 141304                9033             1.540832
# 18                 141304               10143             0.770416
# 19                 141304               10303             2.953261
# 20                 141362                1072             0.513611
# 21                 141362               10162             1.155624
# 22                 141362               16492             2.568053
# 23                 141362               16646             1.412429
# 24                 141362                1522             0.642013
# 25                 141362                8152             1.540832
# 26                 141362                4961             0.770416
# 27                 141362                7757             1.797637
# 28                 141362                1312             0.513611
# 29                 141362               16883             1.412429
# ...                   ...                 ...                  ...
# 935770            3353251               14503             1.470588
# 935771            3353251               14083             1.323529
# 935772            3353251                8083             1.078431
# 935773            3353251               11143             1.960784
# 935774            3353251               12103             2.941176
# 935775            3353251                 883             1.470588
# 935776            3353251                 763             1.470588
# 935777            3353251               13543             1.078431
# 935778            3353251               12163             0.735294
# 935779            3353251                4363             3.431373
# 935780            3353251                3223             0.343137
# 935781            3353251               12223             0.735294
# 935782            3353254                2386             4.767580
# 935783            3353254                6106             7.163290
# 935784            3353254                1306             4.767580
# 935785            3353254                2401            10.131108
# 935786            3353254                5491             2.383790
# 935787            3353254                 286             2.383790
# 935788            3353254                5196             2.979738
# 935789            3353254                5291             3.575685
# 935790            3353254                2101            10.131108
# 935791            3353254                 766             4.767580
# 935792            3353254                 406             5.363528
# 935793            3353254                3516             2.979738
# 935794            3353254                5926             7.151371
# 935795            3353254                4169            19.070322
# 935796            3353254                5326             4.767580
# 935797            3353254                2626            10.131108
# 935798            3353254                3101            15.494636
# 935799            3353254                1414             0.357569
#
# [935800 rows x 3 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
merge1 = pd.merge(merge, intakeOutputUrine,  how='outer', left_on=['patientunitstayid','observationoffset'], right_on = ['patientunitstayid','intakeoutputoffset'])
del merge, intakeOutputUrine
merge1
# Out:
#           patientunitstayid observationoffset  temperature  heartrate  \
# 0                    141227              1162          NaN      100.0
# 1                    141227              1062          NaN      100.0
# 2                    141227              1192          NaN      106.0
# 3                    141227               522          NaN      110.0
# 4                    141227              1197          NaN      106.0
# 5                    141227              1017          NaN       96.0
# 6                    141227              1142          NaN       96.0
# 7                    141227               242          NaN      102.0
# 8                    141227              1127          NaN       96.0
# 9                    141227              1067          NaN      100.0
# 10                   141227              1107          NaN      102.0
# 11                   141227              1417          NaN      124.0
# 12                   141227              1082          NaN      102.0
# 13                   141227              1012          NaN       96.0
# 14                   141227              1087          NaN      100.0
# 15                   141227               502          NaN      112.0
# 16                   141227              1092          NaN      100.0
# 17                   141227               962          NaN      112.0
# 18                   141227              1167          NaN      104.0
# 19                   141227               267          NaN       96.0
# 20                   141227              1097          NaN      102.0
# 21                   141227              1032          NaN       96.0
# 22                   141227              1102          NaN      104.0
# 23                   141227               712          NaN      204.0
# 24                   141227              1187          NaN      104.0
# 25                   141227              1002          NaN       98.0
# 26                   141227              1112          NaN      100.0
# 27                   141227               507          NaN      110.0
# 28                   141227              1172          NaN      102.0
# 29                   141227              1007          NaN       98.0
# ...                     ...               ...          ...        ...
# 41741112            3353251               NaN          NaN        NaN
# 41741113            3353251               NaN          NaN        NaN
# 41741114            3353251               NaN          NaN        NaN
# 41741115            3353251               NaN          NaN        NaN
# 41741116            3353251               NaN          NaN        NaN
# 41741117            3353251               NaN          NaN        NaN
# 41741118            3353251               NaN          NaN        NaN
# 41741119            3353251               NaN          NaN        NaN
# 41741120            3353251               NaN          NaN        NaN
# 41741121            3353251               NaN          NaN        NaN
# 41741122            3353251               NaN          NaN        NaN
# 41741123            3353251               NaN          NaN        NaN
# 41741124            3353254               NaN          NaN        NaN
# 41741125            3353254               NaN          NaN        NaN
# 41741126            3353254               NaN          NaN        NaN
# 41741127            3353254               NaN          NaN        NaN
# 41741128            3353254               NaN          NaN        NaN
# 41741129            3353254               NaN          NaN        NaN
# 41741130            3353254               NaN          NaN        NaN
# 41741131            3353254               NaN          NaN        NaN
# 41741132            3353254               NaN          NaN        NaN
# 41741133            3353254               NaN          NaN        NaN
# 41741134            3353254               NaN          NaN        NaN
# 41741135            3353254               NaN          NaN        NaN
# 41741136            3353254               NaN          NaN        NaN
# 41741137            3353254               NaN          NaN        NaN
# 41741138            3353254               NaN          NaN        NaN
# 41741139            3353254               NaN          NaN        NaN
# 41741140            3353254               NaN          NaN        NaN
# 41741141            3353254               NaN          NaN        NaN
#
#           respiration  systemicsystolic  labresultoffset  creatinine  \
# 0                31.0               NaN              NaN         NaN
# 1                31.0               NaN              NaN         NaN
# 2                35.0             130.0              NaN         NaN
# 3                33.0               NaN              NaN         NaN
# 4                36.0             124.0              NaN         NaN
# 5                35.0              97.0              NaN         NaN
# 6                30.0               NaN              NaN         NaN
# 7                31.0               NaN              NaN         NaN
# 8                29.0               NaN              NaN         NaN
# 9                31.0               NaN              NaN         NaN
# 10               31.0               NaN              NaN         NaN
# 11               31.0              80.0              NaN         NaN
# 12               32.0               NaN              NaN         NaN
# 13               35.0             100.0              NaN         NaN
# 14               31.0               NaN              NaN         NaN
# 15               36.0               NaN              NaN         NaN
# 16               31.0               NaN              NaN         NaN
# 17               51.0               NaN              NaN         NaN
# 18               33.0               NaN              NaN         NaN
# 19               24.0               NaN              NaN         NaN
# 20               33.0               NaN              NaN         NaN
# 21               33.0               NaN              NaN         NaN
# 22               32.0               NaN              NaN         NaN
# 23               41.0              76.0              NaN         NaN
# 24               34.0               NaN              NaN         NaN
# 25               35.0              77.0              NaN         NaN
# 26               29.0               NaN              NaN         NaN
# 27               34.0               NaN              NaN         NaN
# 28               33.0               NaN              NaN         NaN
# 29               34.0              94.0              NaN         NaN
# ...               ...               ...              ...         ...
# 41741112          NaN               NaN              NaN         NaN
# 41741113          NaN               NaN              NaN         NaN
# 41741114          NaN               NaN              NaN         NaN
# 41741115          NaN               NaN              NaN         NaN
# 41741116          NaN               NaN              NaN         NaN
# 41741117          NaN               NaN              NaN         NaN
# 41741118          NaN               NaN              NaN         NaN
# 41741119          NaN               NaN              NaN         NaN
# 41741120          NaN               NaN              NaN         NaN
# 41741121          NaN               NaN              NaN         NaN
# 41741122          NaN               NaN              NaN         NaN
# 41741123          NaN               NaN              NaN         NaN
# 41741124          NaN               NaN              NaN         NaN
# 41741125          NaN               NaN              NaN         NaN
# 41741126          NaN               NaN              NaN         NaN
# 41741127          NaN               NaN              NaN         NaN
# 41741128          NaN               NaN              NaN         NaN
# 41741129          NaN               NaN              NaN         NaN
# 41741130          NaN               NaN              NaN         NaN
# 41741131          NaN               NaN              NaN         NaN
# 41741132          NaN               NaN              NaN         NaN
# 41741133          NaN               NaN              NaN         NaN
# 41741134          NaN               NaN              NaN         NaN
# 41741135          NaN               NaN              NaN         NaN
# 41741136          NaN               NaN              NaN         NaN
# 41741137          NaN               NaN              NaN         NaN
# 41741138          NaN               NaN              NaN         NaN
# 41741139          NaN               NaN              NaN         NaN
# 41741140          NaN               NaN              NaN         NaN
# 41741141          NaN               NaN              NaN         NaN
#
#           wbcx1000  lactate  intakeoutputoffset  urineoutputbyweight
# 0              NaN      NaN                 NaN                  NaN
# 1              NaN      NaN                 NaN                  NaN
# 2              NaN      NaN                 NaN                  NaN
# 3              NaN      NaN                 NaN                  NaN
# 4              NaN      NaN                 NaN                  NaN
# 5              NaN      NaN                 NaN                  NaN
# 6              NaN      NaN                 NaN                  NaN
# 7              NaN      NaN                 NaN                  NaN
# 8              NaN      NaN                 NaN                  NaN
# 9              NaN      NaN                 NaN                  NaN
# 10             NaN      NaN                 NaN                  NaN
# 11             NaN      NaN                 NaN                  NaN
# 12             NaN      NaN                 NaN                  NaN
# 13             NaN      NaN                 NaN                  NaN
# 14             NaN      NaN                 NaN                  NaN
# 15             NaN      NaN                 NaN                  NaN
# 16             NaN      NaN                 NaN                  NaN
# 17             NaN      NaN                 NaN                  NaN
# 18             NaN      NaN                 NaN                  NaN
# 19             NaN      NaN                 NaN                  NaN
# 20             NaN      NaN                 NaN                  NaN
# 21             NaN      NaN                 NaN                  NaN
# 22             NaN      NaN                 NaN                  NaN
# 23             NaN      NaN                 NaN                  NaN
# 24             NaN      NaN                 NaN                  NaN
# 25             NaN      NaN                 NaN                  NaN
# 26             NaN      NaN                 NaN                  NaN
# 27             NaN      NaN                 NaN                  NaN
# 28             NaN      NaN                 NaN                  NaN
# 29             NaN      NaN                 NaN                  NaN
# ...            ...      ...                 ...                  ...
# 41741112       NaN      NaN             14503.0             1.470588
# 41741113       NaN      NaN             14083.0             1.323529
# 41741114       NaN      NaN              8083.0             1.078431
# 41741115       NaN      NaN             11143.0             1.960784
# 41741116       NaN      NaN             12103.0             2.941176
# 41741117       NaN      NaN               883.0             1.470588
# 41741118       NaN      NaN               763.0             1.470588
# 41741119       NaN      NaN             13543.0             1.078431
# 41741120       NaN      NaN             12163.0             0.735294
# 41741121       NaN      NaN              4363.0             3.431373
# 41741122       NaN      NaN              3223.0             0.343137
# 41741123       NaN      NaN             12223.0             0.735294
# 41741124       NaN      NaN              2386.0             4.767580
# 41741125       NaN      NaN              6106.0             7.163290
# 41741126       NaN      NaN              1306.0             4.767580
# 41741127       NaN      NaN              2401.0            10.131108
# 41741128       NaN      NaN              5491.0             2.383790
# 41741129       NaN      NaN               286.0             2.383790
# 41741130       NaN      NaN              5196.0             2.979738
# 41741131       NaN      NaN              5291.0             3.575685
# 41741132       NaN      NaN              2101.0            10.131108
# 41741133       NaN      NaN               766.0             4.767580
# 41741134       NaN      NaN               406.0             5.363528
# 41741135       NaN      NaN              3516.0             2.979738
# 41741136       NaN      NaN              5926.0             7.151371
# 41741137       NaN      NaN              4169.0            19.070322
# 41741138       NaN      NaN              5326.0             4.767580
# 41741139       NaN      NaN              2626.0            10.131108
# 41741140       NaN      NaN              3101.0            15.494636
# 41741141       NaN      NaN              1414.0             0.357569
#
# [41741142 rows x 12 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
merge1['observationoffset'] = merge1.apply(lambda x: x['observationoffset'] if pd.notna(x['observationoffset']) else (x['labresultoffset'] if pd.notna(x['labresultoffset']) else x['intakeoutputoffset']), axis = 1)
merge1 = merge1.drop(['labresultoffset', 'intakeoutputoffset'], axis = 1)
merge1
# Out:
#           patientunitstayid  observationoffset  temperature  heartrate  \
# 0                    141227             1162.0          NaN      100.0
# 1                    141227             1062.0          NaN      100.0
# 2                    141227             1192.0          NaN      106.0
# 3                    141227              522.0          NaN      110.0
# 4                    141227             1197.0          NaN      106.0
# 5                    141227             1017.0          NaN       96.0
# 6                    141227             1142.0          NaN       96.0
# 7                    141227              242.0          NaN      102.0
# 8                    141227             1127.0          NaN       96.0
# 9                    141227             1067.0          NaN      100.0
# 10                   141227             1107.0          NaN      102.0
# 11                   141227             1417.0          NaN      124.0
# 12                   141227             1082.0          NaN      102.0
# 13                   141227             1012.0          NaN       96.0
# 14                   141227             1087.0          NaN      100.0
# 15                   141227              502.0          NaN      112.0
# 16                   141227             1092.0          NaN      100.0
# 17                   141227              962.0          NaN      112.0
# 18                   141227             1167.0          NaN      104.0
# 19                   141227              267.0          NaN       96.0
# 20                   141227             1097.0          NaN      102.0
# 21                   141227             1032.0          NaN       96.0
# 22                   141227             1102.0          NaN      104.0
# 23                   141227              712.0          NaN      204.0
# 24                   141227             1187.0          NaN      104.0
# 25                   141227             1002.0          NaN       98.0
# 26                   141227             1112.0          NaN      100.0
# 27                   141227              507.0          NaN      110.0
# 28                   141227             1172.0          NaN      102.0
# 29                   141227             1007.0          NaN       98.0
# ...                     ...                ...          ...        ...
# 41741112            3353251            14503.0          NaN        NaN
# 41741113            3353251            14083.0          NaN        NaN
# 41741114            3353251             8083.0          NaN        NaN
# 41741115            3353251            11143.0          NaN        NaN
# 41741116            3353251            12103.0          NaN        NaN
# 41741117            3353251              883.0          NaN        NaN
# 41741118            3353251              763.0          NaN        NaN
# 41741119            3353251            13543.0          NaN        NaN
# 41741120            3353251            12163.0          NaN        NaN
# 41741121            3353251             4363.0          NaN        NaN
# 41741122            3353251             3223.0          NaN        NaN
# 41741123            3353251            12223.0          NaN        NaN
# 41741124            3353254             2386.0          NaN        NaN
# 41741125            3353254             6106.0          NaN        NaN
# 41741126            3353254             1306.0          NaN        NaN
# 41741127            3353254             2401.0          NaN        NaN
# 41741128            3353254             5491.0          NaN        NaN
# 41741129            3353254              286.0          NaN        NaN
# 41741130            3353254             5196.0          NaN        NaN
# 41741131            3353254             5291.0          NaN        NaN
# 41741132            3353254             2101.0          NaN        NaN
# 41741133            3353254              766.0          NaN        NaN
# 41741134            3353254              406.0          NaN        NaN
# 41741135            3353254             3516.0          NaN        NaN
# 41741136            3353254             5926.0          NaN        NaN
# 41741137            3353254             4169.0          NaN        NaN
# 41741138            3353254             5326.0          NaN        NaN
# 41741139            3353254             2626.0          NaN        NaN
# 41741140            3353254             3101.0          NaN        NaN
# 41741141            3353254             1414.0          NaN        NaN
#
#           respiration  systemicsystolic  creatinine  wbcx1000  lactate  \
# 0                31.0               NaN         NaN       NaN      NaN
# 1                31.0               NaN         NaN       NaN      NaN
# 2                35.0             130.0         NaN       NaN      NaN
# 3                33.0               NaN         NaN       NaN      NaN
# 4                36.0             124.0         NaN       NaN      NaN
# 5                35.0              97.0         NaN       NaN      NaN
# 6                30.0               NaN         NaN       NaN      NaN
# 7                31.0               NaN         NaN       NaN      NaN
# 8                29.0               NaN         NaN       NaN      NaN
# 9                31.0               NaN         NaN       NaN      NaN
# 10               31.0               NaN         NaN       NaN      NaN
# 11               31.0              80.0         NaN       NaN      NaN
# 12               32.0               NaN         NaN       NaN      NaN
# 13               35.0             100.0         NaN       NaN      NaN
# 14               31.0               NaN         NaN       NaN      NaN
# 15               36.0               NaN         NaN       NaN      NaN
# 16               31.0               NaN         NaN       NaN      NaN
# 17               51.0               NaN         NaN       NaN      NaN
# 18               33.0               NaN         NaN       NaN      NaN
# 19               24.0               NaN         NaN       NaN      NaN
# 20               33.0               NaN         NaN       NaN      NaN
# 21               33.0               NaN         NaN       NaN      NaN
# 22               32.0               NaN         NaN       NaN      NaN
# 23               41.0              76.0         NaN       NaN      NaN
# 24               34.0               NaN         NaN       NaN      NaN
# 25               35.0              77.0         NaN       NaN      NaN
# 26               29.0               NaN         NaN       NaN      NaN
# 27               34.0               NaN         NaN       NaN      NaN
# 28               33.0               NaN         NaN       NaN      NaN
# 29               34.0              94.0         NaN       NaN      NaN
# ...               ...               ...         ...       ...      ...
# 41741112          NaN               NaN         NaN       NaN      NaN
# 41741113          NaN               NaN         NaN       NaN      NaN
# 41741114          NaN               NaN         NaN       NaN      NaN
# 41741115          NaN               NaN         NaN       NaN      NaN
# 41741116          NaN               NaN         NaN       NaN      NaN
# 41741117          NaN               NaN         NaN       NaN      NaN
# 41741118          NaN               NaN         NaN       NaN      NaN
# 41741119          NaN               NaN         NaN       NaN      NaN
# 41741120          NaN               NaN         NaN       NaN      NaN
# 41741121          NaN               NaN         NaN       NaN      NaN
# 41741122          NaN               NaN         NaN       NaN      NaN
# 41741123          NaN               NaN         NaN       NaN      NaN
# 41741124          NaN               NaN         NaN       NaN      NaN
# 41741125          NaN               NaN         NaN       NaN      NaN
# 41741126          NaN               NaN         NaN       NaN      NaN
# 41741127          NaN               NaN         NaN       NaN      NaN
# 41741128          NaN               NaN         NaN       NaN      NaN
# 41741129          NaN               NaN         NaN       NaN      NaN
# 41741130          NaN               NaN         NaN       NaN      NaN
# 41741131          NaN               NaN         NaN       NaN      NaN
# 41741132          NaN               NaN         NaN       NaN      NaN
# 41741133          NaN               NaN         NaN       NaN      NaN
# 41741134          NaN               NaN         NaN       NaN      NaN
# 41741135          NaN               NaN         NaN       NaN      NaN
# 41741136          NaN               NaN         NaN       NaN      NaN
# 41741137          NaN               NaN         NaN       NaN      NaN
# 41741138          NaN               NaN         NaN       NaN      NaN
# 41741139          NaN               NaN         NaN       NaN      NaN
# 41741140          NaN               NaN         NaN       NaN      NaN
# 41741141          NaN               NaN         NaN       NaN      NaN
#
#           urineoutputbyweight
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# ...                       ...
# 41741112             1.470588
# 41741113             1.323529
# 41741114             1.078431
# 41741115             1.960784
# 41741116             2.941176
# 41741117             1.470588
# 41741118             1.470588
# 41741119             1.078431
# 41741120             0.735294
# 41741121             3.431373
# 41741122             0.343137
# 41741123             0.735294
# 41741124             4.767580
# 41741125             7.163290
# 41741126             4.767580
# 41741127            10.131108
# 41741128             2.383790
# 41741129             2.383790
# 41741130             2.979738
# 41741131             3.575685
# 41741132            10.131108
# 41741133             4.767580
# 41741134             5.363528
# 41741135             2.979738
# 41741136             7.151371
# 41741137            19.070322
# 41741138             4.767580
# 41741139            10.131108
# 41741140            15.494636
# 41741141             0.357569
#
# [41741142 rows x 10 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
diagnosis = pd.read_csv('../eICU' + database_type + '/diagnosis.csv')
diagnosis = diagnosis.astype({'diagnosis': int})
diagnosis
# Out:
#         patientunitstayid  diagnosisoffset  diagnosis
# 0                  141227               18          1
# 1                  141288              899          0
# 2                  141288               19          0
# 3                  141288              575          0
# 4                  141288              575          1
# 5                  141288              415          0
# 6                  141288               19          1
# 7                  141288              415          1
# 8                  141288              899          1
# 9                  141289               13          0
# 10                 141289               13          1
# 11                 141297               25          0
# 12                 141297               25          1
# 13                 141304               23          0
# 14                 141304              260          0
# 15                 141304               23          1
# 16                 141304              260          1
# 17                 141314               28          0
# 18                 141314               91          0
# 19                 141314              125          0
# 20                 141314               63          0
# 21                 141362               44          0
# 22                 141392               38          0
# 23                 141392               38          1
# 24                 141432               48          0
# 25                 141432               48          1
# 26                 141454               12          0
# 27                 141462              171          0
# 28                 141462              171          1
# 29                 141470               13          1
# ...                   ...              ...        ...
# 234018            3353197            10988          0
# 234019            3353199               20          1
# 234020            3353199               20          0
# 234021            3353199             4947          1
# 234022            3353199              411          0
# 234023            3353199             4947          0
# 234024            3353199            10418          0
# 234025            3353199              411          1
# 234026            3353235               26          0
# 234027            3353251              108          0
# 234028            3353251              291          0
# 234029            3353251             2653          1
# 234030            3353251              186          0
# 234031            3353251            12374          0
# 234032            3353251             3055          1
# 234033            3353251             1201          0
# 234034            3353251             3055          0
# 234035            3353251            12374          1
# 234036            3353251            11304          0
# 234037            3353251             5521          0
# 234038            3353251             6303          0
# 234039            3353251             4080          0
# 234040            3353251             9169          0
# 234041            3353251             2653          0
# 234042            3353251             9169          1
# 234043            3353251            11304          1
# 234044            3353251             6303          1
# 234045            3353251             5521          1
# 234046            3353251             4080          1
# 234047            3353254               41          0
#
# [234048 rows x 3 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
finalMerge = pd.merge(merge1, diagnosis,  how='outer', left_on=['patientunitstayid','observationoffset'], right_on = ['patientunitstayid', 'diagnosisoffset'])
del merge1, diagnosis
finalMerge['observationoffset'] = finalMerge.apply(lambda x: x['observationoffset'] if pd.notna(x['observationoffset']) else x['diagnosisoffset'], axis = 1)
finalMerge = finalMerge.drop(['diagnosisoffset'], axis = 1)
finalMerge.sort_values(['patientunitstayid','observationoffset'])
finalMerge
# Out:
#           patientunitstayid  observationoffset  temperature  heartrate  \
# 0                    141227             1162.0          NaN      100.0
# 1                    141227             1062.0          NaN      100.0
# 2                    141227             1192.0          NaN      106.0
# 3                    141227              522.0          NaN      110.0
# 4                    141227             1197.0          NaN      106.0
# 5                    141227             1017.0          NaN       96.0
# 6                    141227             1142.0          NaN       96.0
# 7                    141227              242.0          NaN      102.0
# 8                    141227             1127.0          NaN       96.0
# 9                    141227             1067.0          NaN      100.0
# 10                   141227             1107.0          NaN      102.0
# 11                   141227             1417.0          NaN      124.0
# 12                   141227             1082.0          NaN      102.0
# 13                   141227             1012.0          NaN       96.0
# 14                   141227             1087.0          NaN      100.0
# 15                   141227              502.0          NaN      112.0
# 16                   141227             1092.0          NaN      100.0
# 17                   141227              962.0          NaN      112.0
# 18                   141227             1167.0          NaN      104.0
# 19                   141227              267.0          NaN       96.0
# 20                   141227             1097.0          NaN      102.0
# 21                   141227             1032.0          NaN       96.0
# 22                   141227             1102.0          NaN      104.0
# 23                   141227              712.0          NaN      204.0
# 24                   141227             1187.0          NaN      104.0
# 25                   141227             1002.0          NaN       98.0
# 26                   141227             1112.0          NaN      100.0
# 27                   141227              507.0          NaN      110.0
# 28                   141227             1172.0          NaN      102.0
# 29                   141227             1007.0          NaN       98.0
# ...                     ...                ...          ...        ...
# 41945352            3353197             9763.0          NaN        NaN
# 41945353            3353197             9763.0          NaN        NaN
# 41945354            3353197             4566.0          NaN        NaN
# 41945355            3353197             2454.0          NaN        NaN
# 41945356            3353197            16916.0          NaN        NaN
# 41945357            3353197            16916.0          NaN        NaN
# 41945358            3353197             1287.0          NaN        NaN
# 41945359            3353197            10988.0          NaN        NaN
# 41945360            3353197            10988.0          NaN        NaN
# 41945361            3353199               20.0          NaN        NaN
# 41945362            3353199               20.0          NaN        NaN
# 41945363            3353199             4947.0          NaN        NaN
# 41945364            3353199             4947.0          NaN        NaN
# 41945365            3353199            10418.0          NaN        NaN
# 41945366            3353235               26.0          NaN        NaN
# 41945367            3353251              108.0          NaN        NaN
# 41945368            3353251              291.0          NaN        NaN
# 41945369            3353251             2653.0          NaN        NaN
# 41945370            3353251             2653.0          NaN        NaN
# 41945371            3353251              186.0          NaN        NaN
# 41945372            3353251             3055.0          NaN        NaN
# 41945373            3353251             3055.0          NaN        NaN
# 41945374            3353251             1201.0          NaN        NaN
# 41945375            3353251             5521.0          NaN        NaN
# 41945376            3353251             5521.0          NaN        NaN
# 41945377            3353251             6303.0          NaN        NaN
# 41945378            3353251             6303.0          NaN        NaN
# 41945379            3353251             4080.0          NaN        NaN
# 41945380            3353251             4080.0          NaN        NaN
# 41945381            3353254               41.0          NaN        NaN
#
#           respiration  systemicsystolic  creatinine  wbcx1000  lactate  \
# 0                31.0               NaN         NaN       NaN      NaN
# 1                31.0               NaN         NaN       NaN      NaN
# 2                35.0             130.0         NaN       NaN      NaN
# 3                33.0               NaN         NaN       NaN      NaN
# 4                36.0             124.0         NaN       NaN      NaN
# 5                35.0              97.0         NaN       NaN      NaN
# 6                30.0               NaN         NaN       NaN      NaN
# 7                31.0               NaN         NaN       NaN      NaN
# 8                29.0               NaN         NaN       NaN      NaN
# 9                31.0               NaN         NaN       NaN      NaN
# 10               31.0               NaN         NaN       NaN      NaN
# 11               31.0              80.0         NaN       NaN      NaN
# 12               32.0               NaN         NaN       NaN      NaN
# 13               35.0             100.0         NaN       NaN      NaN
# 14               31.0               NaN         NaN       NaN      NaN
# 15               36.0               NaN         NaN       NaN      NaN
# 16               31.0               NaN         NaN       NaN      NaN
# 17               51.0               NaN         NaN       NaN      NaN
# 18               33.0               NaN         NaN       NaN      NaN
# 19               24.0               NaN         NaN       NaN      NaN
# 20               33.0               NaN         NaN       NaN      NaN
# 21               33.0               NaN         NaN       NaN      NaN
# 22               32.0               NaN         NaN       NaN      NaN
# 23               41.0              76.0         NaN       NaN      NaN
# 24               34.0               NaN         NaN       NaN      NaN
# 25               35.0              77.0         NaN       NaN      NaN
# 26               29.0               NaN         NaN       NaN      NaN
# 27               34.0               NaN         NaN       NaN      NaN
# 28               33.0               NaN         NaN       NaN      NaN
# 29               34.0              94.0         NaN       NaN      NaN
# ...               ...               ...         ...       ...      ...
# 41945352          NaN               NaN         NaN       NaN      NaN
# 41945353          NaN               NaN         NaN       NaN      NaN
# 41945354          NaN               NaN         NaN       NaN      NaN
# 41945355          NaN               NaN         NaN       NaN      NaN
# 41945356          NaN               NaN         NaN       NaN      NaN
# 41945357          NaN               NaN         NaN       NaN      NaN
# 41945358          NaN               NaN         NaN       NaN      NaN
# 41945359          NaN               NaN         NaN       NaN      NaN
# 41945360          NaN               NaN         NaN       NaN      NaN
# 41945361          NaN               NaN         NaN       NaN      NaN
# 41945362          NaN               NaN         NaN       NaN      NaN
# 41945363          NaN               NaN         NaN       NaN      NaN
# 41945364          NaN               NaN         NaN       NaN      NaN
# 41945365          NaN               NaN         NaN       NaN      NaN
# 41945366          NaN               NaN         NaN       NaN      NaN
# 41945367          NaN               NaN         NaN       NaN      NaN
# 41945368          NaN               NaN         NaN       NaN      NaN
# 41945369          NaN               NaN         NaN       NaN      NaN
# 41945370          NaN               NaN         NaN       NaN      NaN
# 41945371          NaN               NaN         NaN       NaN      NaN
# 41945372          NaN               NaN         NaN       NaN      NaN
# 41945373          NaN               NaN         NaN       NaN      NaN
# 41945374          NaN               NaN         NaN       NaN      NaN
# 41945375          NaN               NaN         NaN       NaN      NaN
# 41945376          NaN               NaN         NaN       NaN      NaN
# 41945377          NaN               NaN         NaN       NaN      NaN
# 41945378          NaN               NaN         NaN       NaN      NaN
# 41945379          NaN               NaN         NaN       NaN      NaN
# 41945380          NaN               NaN         NaN       NaN      NaN
# 41945381          NaN               NaN         NaN       NaN      NaN
#
#           urineoutputbyweight  diagnosis
# 0                         NaN        NaN
# 1                         NaN        NaN
# 2                         NaN        NaN
# 3                         NaN        NaN
# 4                         NaN        NaN
# 5                         NaN        NaN
# 6                         NaN        NaN
# 7                         NaN        NaN
# 8                         NaN        NaN
# 9                         NaN        NaN
# 10                        NaN        NaN
# 11                        NaN        NaN
# 12                        NaN        NaN
# 13                        NaN        NaN
# 14                        NaN        NaN
# 15                        NaN        NaN
# 16                        NaN        NaN
# 17                        NaN        NaN
# 18                        NaN        NaN
# 19                        NaN        NaN
# 20                        NaN        NaN
# 21                        NaN        NaN
# 22                        NaN        NaN
# 23                        NaN        NaN
# 24                        NaN        NaN
# 25                        NaN        NaN
# 26                        NaN        NaN
# 27                        NaN        NaN
# 28                        NaN        NaN
# 29                        NaN        NaN
# ...                       ...        ...
# 41945352                  NaN        0.0
# 41945353                  NaN        1.0
# 41945354                  NaN        0.0
# 41945355                  NaN        0.0
# 41945356                  NaN        0.0
# 41945357                  NaN        1.0
# 41945358                  NaN        0.0
# 41945359                  NaN        1.0
# 41945360                  NaN        0.0
# 41945361                  NaN        1.0
# 41945362                  NaN        0.0
# 41945363                  NaN        1.0
# 41945364                  NaN        0.0
# 41945365                  NaN        0.0
# 41945366                  NaN        0.0
# 41945367                  NaN        0.0
# 41945368                  NaN        0.0
# 41945369                  NaN        1.0
# 41945370                  NaN        0.0
# 41945371                  NaN        0.0
# 41945372                  NaN        1.0
# 41945373                  NaN        0.0
# 41945374                  NaN        0.0
# 41945375                  NaN        0.0
# 41945376                  NaN        1.0
# 41945377                  NaN        0.0
# 41945378                  NaN        1.0
# 41945379                  NaN        0.0
# 41945380                  NaN        1.0
# 41945381                  NaN        0.0
#
# [41945382 rows x 11 columns]
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'

# %%
path = "../eICU/training/"
finalMerge.to_csv(path + "finalMerge.csv", sep=',', index=False, encoding='utf-8')
# Out:
# Error in callback <bound method AutoreloadMagics.post_execute_hook of <autoreload.AutoreloadMagics object at 0x7f45067d2048>> (for post_execute):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in post_execute_hook(self)
#     536         newly_loaded_modules = set(sys.modules) - self.loaded_modules
#     537         for modname in newly_loaded_modules:
# --> 538             _, pymtime = self._reloader.filename_and_mtime(sys.modules[modname])
#     539             if pymtime is not None:
#     540                 self._reloader.modules_mtimes[modname] = pymtime
#
# /usr/local/lib/python3.6/dist-packages/IPython/extensions/autoreload.py in filename_and_mtime(self, module)
#     182
#     183     def filename_and_mtime(self, module):
# --> 184         if not hasattr(module, '__file__') or module.__file__ is None:
#     185             return None, None
#     186
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in __getattribute__(self, name)
#     193         def __getattribute__(self, name):
#     194             try:
# --> 195                 return getattr(getmod(), name)
#     196             except ImportError:
#     197                 return None
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in getmod()
#     177     def getmod():
#     178         if not mod:
# --> 179             x = importobj(modpath, None)
#     180             if attrname is not None:
#     181                 x = getattr(x, attrname)
#
# /usr/lib/python3/dist-packages/py/_vendored_packages/apipkg.py in importobj(modpath, attrname)
#      67
#      68 def importobj(modpath, attrname):
# ---> 69     module = __import__(modpath, None, None, ['__doc__'])
#      70     if not attrname:
#      71         return module
#
# /usr/lib/python3/dist-packages/pytest.py in <module>
#      11     hookspec, hookimpl
#      12 )
# ---> 13 from _pytest.fixtures import fixture, yield_fixture
#      14 from _pytest.assertion import register_assert_rewrite
#      15 from _pytest.freeze_support import freeze_includes
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in <module>
#     840
#     841 @attr.s(frozen=True)
# --> 842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
#     844     params = attr.ib(convert=attr.converters.optional(tuple))
#
# /usr/lib/python3/dist-packages/_pytest/fixtures.py in FixtureFunctionMarker()
#     842 class FixtureFunctionMarker(object):
#     843     scope = attr.ib()
# --> 844     params = attr.ib(convert=attr.converters.optional(tuple))
#     845     autouse = attr.ib(default=False)
#     846     ids = attr.ib(default=None, convert=_ensure_immutable_ids)
#
# TypeError: attrib() got an unexpected keyword argument 'convert'
