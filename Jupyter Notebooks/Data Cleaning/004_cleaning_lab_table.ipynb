# %%
import pandas as pd

# %% [markdown]
# The `lab` table provides Laboratory tests that have have been mapped to a standard set of measurements.
# Unmapped measurements are recorded in the customLab table.
# See: http://eicu-crd.mit.edu/eicutables/lab/

# %% [markdown]
# #### Reading in lab dataset and keeping relevant columns to our study.

# %%
databasePath = "../../eICU/full/"
exportPath = "../../eICU/training/"

# %%
columns = ['patientunitstayid', 'labresultoffset', 'labname', 'labresult']
lab = pd.read_csv(databasePath + 'lab.csv', usecols=columns)
lab
# Out:
#           patientunitstayid  labresultoffset             labname  labresult
# 0                    141168             2026          fibrinogen     177.00
# 1                    141168             1133            PT - INR       2.50
# 2                    141168             2026           magnesium       2.00
# 3                    141168             1133                  PT      26.60
# 4                    141168             2141                  pH       7.20
# 5                    141168              231            PT - INR       1.70
# 6                    141168             1701  urinary creatinine     173.12
# 7                    141168             2026                 MCH      29.20
# 8                    141168              516                 BUN      26.00
# 9                    141168             1701      urinary sodium      12.00
# 10                   141168             2141                HCO3      14.00
# 11                   141168              231                  PT      17.10
# 12                   141168             2026             lactate      12.20
# 13                   141168             2026                 BUN      29.00
# 14                   141168             2026                 CPK     216.00
# 15                   141168              231                 PTT      29.00
# 16                   141168             2141                FiO2        NaN
# 17                   141168              516             -lymphs      19.00
# 18                   141168             2026        Base Deficit      17.00
# 19                   141168             2026                 BNP     623.00
# 20                   141168             1133            chloride     101.00
# 21                   141168             1136           uric acid       8.10
# 22                   141168             2141        Base Deficit      13.00
# 23                   141168             2026        troponin - I       0.26
# 24                   141168             2026                paO2      68.00
# 25                   141168             2026                -eos       0.00
# 26                   141168             1805                HCO3      15.00
# 27                   141168             2026                HCO3      11.00
# 28                   141168             2141                paO2     121.00
# 29                   141168             1133    platelets x 1000     213.00
# ...                     ...              ...                 ...        ...
# 39132501            3353263               -7              CPK-MB       1.10
# 39132502            3353263             2650                 PTT      53.00
# 39132503            3353263               -7                 MPV       7.20
# 39132504            3353263               -7                 CPK     133.00
# 39132505            3353263             1733                 PTT      50.00
# 39132506            3353263               -7        CPK-MB INDEX       0.80
# 39132507            3353263               -7    platelets x 1000     161.00
# 39132508            3353263             6919                 PTT      51.00
# 39132509            3353263             7490          WBC x 1000       4.50
# 39132510            3353263             1109                 PTT      60.00
# 39132511            3353263               -7                 MCH      27.00
# 39132512            3353263             6446                 PTT      87.00
# 39132513            3353263             1733                 MPV       7.20
# 39132514            3353263               -7                 Hgb      14.90
# 39132515            3353263             7490                 MPV       7.00
# 39132516            3353263               -7    platelets x 1000     164.00
# 39132517            3353263             1733                 MCV      82.00
# 39132518            3353263               -7                MCHC      33.00
# 39132519            3353263             1733    platelets x 1000     169.00
# 39132520            3353263              -37                 PTT      25.00
# 39132521            3353263             1733                MCHC      34.00
# 39132522            3353263               -7                 MCH      27.00
# 39132523            3353263             1733                 Hct      38.00
# 39132524            3353263               -7                 RDW      13.30
# 39132525            3353263             1733                 Hgb      12.90
# 39132526            3353263               -7          WBC x 1000       6.40
# 39132527            3353263             1733                 RBC       4.67
# 39132528            3353263               -7              -monos      10.00
# 39132529            3353263             1733          WBC x 1000       6.60
# 39132530            3353263             1733                 MCH      28.00
#
# [39132531 rows x 4 columns]

# %% [markdown]
# #### Reading in patient ids to keep

# %%
patientIds = pd.read_csv('../../eICU' + '/training' + '/patientIds.csv')
patientIds = patientIds['patientunitstayid'].tolist()
print('Number of unique patients: ', len(patientIds))

# %% [markdown]
# #### Keeping patient ids from lab table that exist in patient id file

# %%
lab = lab.loc[lab['patientunitstayid'].isin(patientIds)]
lab
# Out:
#           patientunitstayid  labresultoffset           labname  labresult
# 815                  141227              417         magnesium       2.00
# 816                  141227             1467           lactate       1.20
# 817                  141227              -13           -lymphs      15.00
# 818                  141227              417         potassium       4.00
# 819                  141227              -13              HCO3      11.00
# 820                  141227             1362               BUN      32.00
# 821                  141227              -13              MCHC      30.10
# 822                  141227             -128               Hgb       8.40
# 823                  141227              -13           lactate       4.30
# 824                  141227            -1566               RDW      22.40
# 825                  141227              -13               RBC       3.25
# 826                  141227              937         magnesium       1.90
# 827                  141227              -13             paCO2      20.00
# 828                  141227             1647              paO2     142.00
# 829                  141227              -13               RDW      22.80
# 830                  141227             1362               MCV      85.60
# 831                  141227              -13                pH       7.37
# 832                  141227              -13         magnesium       2.10
# 833                  141227              -13               MCV      88.00
# 834                  141227             -128               MCV      87.10
# 835                  141227              -13              paO2      64.00
# 836                  141227              937          chloride     101.00
# 837                  141227              -13               MCH      26.50
# 838                  141227             1362       bicarbonate      17.00
# 839                  141227              -13              FiO2      36.00
# 840                  141227             1647      Base Deficit       9.00
# 841                  141227              -13               Hct      28.60
# 842                  141227             1654      troponin - I       0.50
# 843                  141227              -13      Base Deficit      13.00
# 844                  141227             1362           glucose     128.00
# ...                     ...              ...               ...        ...
# 39132400            3353254             -256         anion gap       8.00
# 39132401            3353254             4143  platelets x 1000     158.00
# 39132402            3353254              673               Hgb       9.20
# 39132403            3353254             1218              -eos       0.00
# 39132404            3353254             -256        creatinine       2.38
# 39132405            3353254             4143               RDW      16.30
# 39132406            3353254             -256         potassium       5.00
# 39132407            3353254             1218            -basos       0.00
# 39132408            3353254             -256           glucose     181.00
# 39132409            3353254             4143               MPV       8.40
# 39132410            3353254             -256           calcium       8.90
# 39132411            3353254             1218              MCHC      33.00
# 39132412            3353254             -256            sodium     141.00
# 39132413            3353254             4143               Hgb       9.70
# 39132414            3353254             -256       bicarbonate      24.00
# 39132415            3353254             1218               Hgb       8.20
# 39132416            3353254             -256               BUN      42.00
# 39132417            3353254             4143               RBC       3.15
# 39132418            3353254             -256          chloride     109.00
# 39132419            3353254             1218               RBC       2.75
# 39132420            3353254             4144       bicarbonate      23.00
# 39132421            3353254             1218               MCH      30.00
# 39132422            3353254             4144               BUN      21.00
# 39132423            3353254             1218               Hct      25.00
# 39132424            3353254             4144          chloride     112.00
# 39132425            3353254             1218               MCV      92.00
# 39132426            3353254             4144         potassium       4.20
# 39132427            3353254             -256            lipase      53.00
# 39132428            3353254             4144            sodium     140.00
# 39132429            3353254             4144         magnesium       1.40
#
# [11280451 rows x 4 columns]

# %% [markdown]
# #### Updating patient ids with patient ids that remain from dataset

# %%
newPatientIds = pd.DataFrame(lab['patientunitstayid'].unique())
newPatientIds.rename(columns={0: 'patientunitstayid'}, inplace=True)
newPatientIds
# Out:
#        patientunitstayid
# 0                 141227
# 1                 141288
# 2                 141289
# 3                 141297
# 4                 141304
# 5                 141314
# 6                 141362
# 7                 141392
# 8                 141432
# 9                 141454
# 10                141462
# 11                141470
# 12                141604
# 13                141631
# 14                141649
# 15                141751
# 16                141816
# 17                141893
# 18                141920
# 19                141944
# 20                141945
# 21                142195
# 22                142209
# 23                142388
# 24                142440
# 25                142478
# 26                142636
# 27                142814
# 28                142885
# 29                143056
# ...                  ...
# 43610            3352460
# 43611            3352481
# 43612            3352510
# 43613            3352533
# 43614            3352614
# 43615            3352633
# 43616            3352634
# 43617            3352637
# 43618            3352721
# 43619            3352727
# 43620            3352737
# 43621            3352827
# 43622            3352830
# 43623            3352940
# 43624            3352961
# 43625            3352986
# 43626            3353007
# 43627            3353031
# 43628            3353056
# 43629            3353127
# 43630            3353140
# 43631            3353144
# 43632            3353145
# 43633            3353190
# 43634            3353196
# 43635            3353197
# 43636            3353199
# 43637            3353235
# 43638            3353251
# 43639            3353254
#
# [43640 rows x 1 columns]

# %%
newPatientIds.to_csv(exportPath + "patientIds.csv", sep=',', index=False, encoding='utf-8')

# %%
del newPatientIds, patientIds

# %% [markdown]
# #### Keeping lab results relevant to diagnosing sepsis

# %%
# converting labname 'urinary creatinine to 'creatinine'
lab.loc[lab['labname'].str.contains("urinary creatinine"), 'labname'] = "creatinine"

# Only keeping rows where labname is 'WBC x 1000', 'lactate', 'creatinine'
labName = ['WBC x 1000', 'lactate', 'creatinine']
lab = lab[lab.labname.isin(labName)]
# Out:
# /usr/lib/python3/dist-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %% [markdown]
# #### Transposing Lab Names and their results into columns.

# %%
# duplicating labs to transpose labresult and labname
labc = lab.copy()
labw = lab.copy()
labl = lab.copy()

labc = labc.loc[(labc['labname'].str.contains("creatinine"))]
labw = labw.loc[(labw['labname'].str.contains("WBC x 1000"))]
labl = labl.loc[(labl['labname'].str.contains("lactate"))]

# Transpose labresults and lab name to cols
labc['creatinine'] = labc.apply(lambda x: x['labresult'] if x['labname'] == 'creatinine' else -1, axis=1)
labw['wbcx1000'] = labw.apply(lambda x: x['labresult'] if x['labname'] == 'WBC x 1000' else -1, axis=1)
labl['lactate'] = labl.apply(lambda x: x['labresult'] if x['labname'] == 'lactate' else -1, axis=1)

labc = labc.drop(['labname', 'labresult'], axis = 1)
labw = labw.drop(['labname', 'labresult'], axis = 1)
labl = labl.drop(['labname', 'labresult'], axis = 1)

# %% [markdown]
# #### Merging Lab Dataframes into Final Lab Dataset

# %%
# merge lab results dataframes
finalLab = labc.merge(labw, how = 'left', on = ['patientunitstayid', 'labresultoffset'])
finalLab = finalLab.merge(labl, how = 'left', on = ['patientunitstayid', 'labresultoffset'])
finalLab = finalLab.drop_duplicates()
finalLab
# Out:
#         patientunitstayid  labresultoffset  creatinine  wbcx1000  lactate
# 0                  141227             1362        1.90      42.7      NaN
# 1                  141227            -1566        1.40      48.2      NaN
# 2                  141227              -13        1.50      65.9      4.3
# 3                  141227              937        1.60       NaN      NaN
# 4                  141227             -128        1.40      47.7      NaN
# 5                  141288             3697        0.60      11.5      NaN
# 6                  141288             2202        0.66      16.0      NaN
# 7                  141288             6544        0.54      13.0      NaN
# 8                  141288             5097        0.71      11.9      NaN
# 9                  141288              797        0.73      16.3      1.1
# 10                 141288             -268        0.95       6.9      3.2
# 11                 141289              595        0.60       7.1      NaN
# 12                 141297             1838        4.37      16.8     15.5
# 13                 141297              788        6.18      11.4      NaN
# 14                 141297              193        5.69      17.3      3.0
# 15                 141304             -127        2.34      16.4      1.5
# 16                 141304             2978        1.47      15.5      NaN
# 17                 141304             1606        1.28      11.8      NaN
# 18                 141304             4409        1.29      13.6      NaN
# 19                 141304             5800        1.24      12.6      NaN
# 20                 141304               93        2.05      12.8      NaN
# 21                 141304             7293        1.29      11.7      NaN
# 22                 141314               33        1.67       5.8     23.5
# 23                 141314              507        1.91       1.9     20.5
# 24                 141314              343        1.84       4.0      NaN
# 25                 141362            18067        1.06      10.7      NaN
# 26                 141362            16637        0.92      10.0      NaN
# 27                 141362            10871        1.00      14.9      NaN
# 28                 141362              746        1.13      10.3      NaN
# 29                 141362             -639        1.11      14.2      NaN
# ...                   ...              ...         ...       ...      ...
# 364148            3353199             8559        0.76       NaN      NaN
# 364149            3353199             2461        0.96       5.7      NaN
# 364150            3353199             5335        0.71       NaN      NaN
# 364151            3353235             -310        1.04       5.4      NaN
# 364152            3353235             1738        1.19       NaN      NaN
# 364153            3353251            11058        3.98      17.6      NaN
# 364154            3353251            13970        4.02       NaN      NaN
# 364155            3353251            18327        2.28      18.3      NaN
# 364156            3353251             8246        3.29      13.6      NaN
# 364157            3353251            16867        2.78       NaN      NaN
# 364158            3353251            12458        3.94      18.6      NaN
# 364159            3353251             9644        3.79      15.4      NaN
# 364160            3353251              765        2.65      25.9      NaN
# 364161            3353251            15598        3.23       NaN      NaN
# 364162            3353251             1490        2.40      20.8      NaN
# 364163            3353251              995        2.60      21.5      NaN
# 364164            3353251             3863        3.40      14.4      NaN
# 364165            3353251             2541        3.08      26.1      NaN
# 364166            3353251             1127        2.41      20.4      NaN
# 364167            3353251             -217        1.81       NaN      NaN
# 364168            3353251             5459        3.29      11.9      NaN
# 364169            3353251             6868        3.35      13.0      NaN
# 364170            3353251             1849        2.46      25.9      NaN
# 364171            3353251              409        2.43       NaN      NaN
# 364172            3353254             2610        1.92       9.8      NaN
# 364173            3353254             1844        2.22       NaN      NaN
# 364174            3353254             1218        2.21      15.3      NaN
# 364175            3353254             5558        1.67      11.7      NaN
# 364176            3353254             4144        1.61       NaN      NaN
# 364177            3353254             -256        2.38      13.5      NaN
#
# [363179 rows x 5 columns]

# %% [markdown]
# #### Saving the Cleaned Patient DataFrame to a `csv` file

# %%
finalLab.to_csv(exportPath + "lab.csv", sep=',', index=False, encoding='utf-8')
